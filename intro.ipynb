# %% [markdown]
# <a href="https://colab.research.google.com/github/gregor-EM/data-science-bootcamp/blob/main/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome Greg")
age = 22
print(age)
# Out:
# Welcome Greg
# 22
